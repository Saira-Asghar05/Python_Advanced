# %% [markdown]
# #**Sets**
#
# Like lists and tuples, sets are used to store multiple values of different data types in a single variable.
#
# Set items are unordered, unindexed, unchangable and don't allow duplicate values.
#
# (Though set items are unmutable, we can still add and remove items).
#
# Sets are written with curly brackets.

# %%
set1 = {"Lahore", "Faisalabad", 5, True}
print(set1)
print(type(set1))

# %%
# Duplicates not allowed in sets
# set1 = {"Lahore", "Faisalabad", 5, True, "Lahore"}
# print(set1)
set2 = {5, True, 1}
print(set2)

# %% [markdown]
# #**Length of a Set**
#
# To determine how many items a set has, use the `len()` function.

# %%
set1 = {"Lahore", "Faisalabad", 5, True, 5, "lahore"}
print(len(set1))

# %% [markdown]
# #**Access Set Items**
#
# You cannot access items in a set by referring to an index or a key.
#
# But you can loop through the set items using a `for` loop, or ask if a specified value is present in a set, by using the `in` keyword.

# %%
set1 = {"Lahore", "Faisalabad", 5, 5, True}
for i in set1:
  print(i)

for j in set1:
  print(j)

# %%
set1 = {"Lahore", "Faisalabad", 5, True}
print("Lahore" in set1)

# %% [markdown]
# #**Add items in a Set**
#
# Once a set is created, you cannot change its items, but you can add new items.
#
# To add an item to a set, use the `add()` method.
#
# To add items from another set into the current set, use the `update()` method.

# %%
set1 = {"Lahore", "Faisalabad", 5, True}
set1.add("Peshawar")
print(set1)

# %%
set1 = {"Lahore", "Faisalabad", 5, True}
# set2 = {5, 0, False}
# set1.update(set2)
# print(set1)

mylist = [4, 7, 88]
set1.update(mylist)
print(set1)

# %% [markdown]
# #**Remove Set Items**

# %%
set1 = {"Lahore", "Faisalabad", 5, True}
print(set1.remove("Lahohjk"))
print(x)

set1 = {"Lahore", "Faisalabad", 5, True}
set1.discard("gjhl")
print(set1)

# %%
set1 = {"Lahore", "Faisalabad", 5, True}
set1.pop()
print(set1)

# %%
set1 = {"Lahore", "Faisalabad", 5, True}
set1.clear()
print(set1)

# %%
set1 = {"Lahore", "Faisalabad", 5, True}
del set1
print(set1)

# %% [markdown]
# #**Join Sets**

# %%
set1 = {"Lahore", "Faisalabad", 5, True}
set2 = {5, 0, False}

set1.union(set2)
print(set1)

# %%
set1 = {"Lahore", "Faisalabad", 5, True}
set2 = {5, 0, False}
set1.update(set2)
print(set1)

# %% [markdown]
# #**Some Set Methods**
#
# * `intersection_update()`
# * `intersection()`
# * `symmetric_difference()`
# * `difference()`

# %%
#The intersection_update() method will keep only the items that are present in both sets.
set1 = {"Lahore", "Faisalabad", 5, True}
set2 = {5, 0, False}
set1.intersection_update(set2)
print(set1)

# %%
#The intersection() method will return a new set, that only contains the items that are present in both sets.

set1 = {"Lahore", "Faisalabad", 5, True}
set2 = {5, 0, False}
x = set1.intersection(set2)
print(set1)

# %%
#difference method Returns a set containing the difference between two or more sets

set1 = {"Lahore", "Faisalabad", 5, True}
set2 = {5, 0, False}
x = set1.difference(set2)
print(x)

# %%
'''The symmetric_difference() method will return a new set, that contains only 
the elements that are NOT present in both sets.'''

set1 = {"Lahore", "Faisalabad", 5, True}
set2 = {5, 0, False}
a = set1.symmetric_difference(set2)
print(a)

# %% [markdown]
# ![Screenshot (382).png](data:image/png;base64,...)
